# %%
# !pip install ultralytics opencv-python matplotlib
# Out:
# Requirement already satisfied: ultralytics in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (8.3.229)
# Requirement already satisfied: opencv-python in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (4.11.0.86)
# Requirement already satisfied: matplotlib in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (3.10.1)
# Requirement already satisfied: numpy<=2.3.4,>=1.23.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: pillow<=12.0.0,>=7.1.2 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (11.1.0)
# Requirement already satisfied: pyyaml<=6.0.3,>=5.3.1 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests<=2.32.5,>=2.23.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (2.32.5)
# Requirement already satisfied: scipy<=1.16.3,>=1.4.1 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (1.15.2)
# Requirement already satisfied: torch!=2.4.0,<=2.9.1,>=1.8.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (2.9.1)
# Requirement already satisfied: torchvision<=0.24.1,>=0.9.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (0.24.1)
# Requirement already satisfied: psutil<=7.1.3,>=5.8.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (7.1.3)
# Requirement already satisfied: polars<=1.35.2,>=0.20.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (1.35.2)
# Requirement already satisfied: ultralytics-thop<=2.0.18 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (2.0.18)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.35.2 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from polars<=1.35.2,>=0.20.0->ultralytics) (1.35.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from requests<=2.32.5,>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from requests<=2.32.5,>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from requests<=2.32.5,>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from requests<=2.32.5,>=2.23.0->ultralytics) (2025.10.5)
# Requirement already satisfied: filelock in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from torch!=2.4.0,<=2.9.1,>=1.8.0->ultralytics) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from torch!=2.4.0,<=2.9.1,>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from torch!=2.4.0,<=2.9.1,>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from torch!=2.4.0,<=2.9.1,>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from torch!=2.4.0,<=2.9.1,>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from torch!=2.4.0,<=2.9.1,>=1.8.0->ultralytics) (2025.10.0)
# Requirement already satisfied: six>=1.5 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from sympy>=1.13.3->torch!=2.4.0,<=2.9.1,>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from jinja2->torch!=2.4.0,<=2.9.1,>=1.8.0->ultralytics) (3.0.3)

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

# %%
# Training was already performed earlier.
# This cell shows the training configuration.

model = YOLO("yolov8n.pt")

# model.train(
#     data="data.yaml",
#     epochs=50,
#     imgsz=640
# )

# %%
model = YOLO("runs/detect/train4/weights/best.pt")

# %%
img = cv2.imread("predict/test.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(8,6))
plt.imshow(img)
plt.axis("off")
# Out:
# (-0.5, 611.5, 407.5, -0.5)

# %%
img = cv2.imread("predict/test1.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(8,6))
plt.imshow(img)
plt.axis("off")
# Out:
# (-0.5, 611.5, 406.5, -0.5)

# %%
img = cv2.imread("predict/test2.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(8,6))
plt.imshow(img)
plt.axis("off")
# Out:
# (-0.5, 611.5, 407.5, -0.5)
